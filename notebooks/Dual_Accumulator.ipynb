# %%
import autograd.numpy as np
import autograd.numpy.random as npr
import os
import sys

# Install package dependencies for rSLDS modeling
# !pip install git+https://github.com/slinderman/ssm.git#egg=ssm

# Clone and install ssmdm
repo_dir = "ssmdm"
if os.path.exists(repo_dir):
    print(f"Removing existing {repo_dir} directory...")
    # !rm -rf {repo_dir}

print(f"Cloning {repo_dir} repository...")
# !git clone https://github.com/davidzoltowski/ssmdm.git

print(f"Installing {repo_dir} in editable mode...")
# !pip install -e {repo_dir}

# Add the cloned repository to sys.path explicitly
if repo_dir not in sys.path:
    sys.path.insert(0, repo_dir)


import types
from autograd.scipy.special import logsumexp

# Create fake module
fake_misc = types.ModuleType("autograd.scipy.misc")
fake_misc.logsumexp = logsumexp

# Inject into sys.modules so imports will find it
sys.modules["autograd.scipy.misc"] = fake_misc



from ssmdm.accumulation import Accumulation, LatentAccumulation

import copy
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("ticks")
sns.set_context("talk")
from ssmdm.misc import smooth, generate_clicks, generate_clicks_D
from ssm.util import softplus
from ssm.primitives import blocks_to_full
npr.seed(1234)

print("All imports successful!")
# Out:
# Collecting ssm
#   Cloning https://github.com/slinderman/ssm.git to /tmp/pip-install-z3pggiwg/ssm_98638e63f3344d82a1046322fba0105f
#   Running command git clone --filter=blob:none --quiet https://github.com/slinderman/ssm.git /tmp/pip-install-z3pggiwg/ssm_98638e63f3344d82a1046322fba0105f
#   Resolved https://github.com/slinderman/ssm.git to commit eb6c8aa33e5311d3564075807dec340759dd8081
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.12/dist-packages (from ssm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from ssm) (1.16.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from ssm) (0.60.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from ssm) (1.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from ssm) (4.67.1)
# Requirement already satisfied: autograd in /usr/local/lib/python3.12/dist-packages (from ssm) (1.8.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from ssm) (3.0.12)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->ssm) (0.43.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->ssm) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->ssm) (3.6.0)
# Removing existing ssmdm directory...
# Cloning ssmdm repository...
# Cloning into 'ssmdm'...
# remote: Enumerating objects: 389, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 389 (delta 4), reused 11 (delta 3), pack-reused 374 (from 1)
# Receiving objects: 100% (389/389), 3.93 MiB | 5.74 MiB/s, done.
# Resolving deltas: 100% (226/226), done.
# Installing ssmdm in editable mode...
# Obtaining file:///content/ssmdm
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ssmdm==0.1.0) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from ssmdm==0.1.0) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from ssmdm==0.1.0) (3.10.0)
# Requirement already satisfied: ssm in /usr/local/lib/python3.12/dist-packages (from ssmdm==0.1.0) (0.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->ssmdm==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->ssmdm==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->ssmdm==0.1.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->ssmdm==0.1.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->ssmdm==0.1.0) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->ssmdm==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->ssmdm==0.1.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->ssmdm==0.1.0) (2.9.0.post0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from ssm->ssmdm==0.1.0) (1.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from ssm->ssmdm==0.1.0) (4.67.1)
# Requirement already satisfied: autograd in /usr/local/lib/python3.12/dist-packages (from ssm->ssmdm==0.1.0) (1.8.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->ssmdm==0.1.0) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->ssm->ssmdm==0.1.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->ssm->ssmdm==0.1.0) (3.6.0)
# Installing collected packages: ssmdm
#   Running setup.py develop for ssmdm
# Successfully installed ssmdm-0.1.0
# All imports successful!

# %%
# 2D Accumulator with Poisson observations
D = 2   # number of accumulation dimensions
K = 3   # number of discrete states
M = 2   # number of input dimensions
N = 15  # number of observations
bin_size = 0.01
latent_acc = LatentAccumulation(N, K, D, M=M,
                                transitions="race",
                                emissions="poisson",
                                emission_kwargs={"bin_size":bin_size})

# set params
betas = 0.05*np.ones((D,))
sigmas = np.log(1e-3)*np.ones((D,))
latent_acc.dynamics.params = (betas, sigmas, latent_acc.dynamics.params[2])
latent_acc.emissions.Cs[0] = 4 * npr.randn(N,D) + npr.choice([-15,15],(N,D))
latent_acc.emissions.ds[0] = 40 + 4.0 * npr.randn(N)

# %%
# Sample state trajectories
T = 100 # number of time bins
trial_time = 1.0 # trial length in seconds
dt = 0.01 # bin size in seconds
N_samples = 250

# input statistics
total_rate = 40 # the sum of the right and left poisson process rates is 40

us = []
zs = []
xs = []
ys = []

for smpl in range(N_samples):

    # randomly draw right and left rates
    rate_r = np.random.randint(0,total_rate+1)
    rate_l = total_rate - rate_r
    rates = [rate_r,rate_l]

    # generate binned right and left clicks
    u = generate_clicks_D(rates,T=trial_time,dt=dt)

    # input is sum of u_r and u_l
    u = 1.0*np.array(u).T
    z, x, y = latent_acc.sample(T, input=u)

    us.append(u)
    zs.append(z)
    xs.append(x)
    ys.append(y)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2470753241.py in <cell line: 0>()
#      15
#      16 # Import InitialStateDistribution to explicitly re-initialize it
# ---> 17 from ssm.core.initial_states import InitialStateDistribution
#      18
#      19 for smpl in range(N_samples):
#
# ModuleNotFoundError: No module named 'ssm.core'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# initialize test model
test_acc = LatentAccumulation(N, K, D, M=M,
                              transitions="race",
                              emissions="poisson",
                              emission_kwargs={"bin_size":bin_size})
betas0 = 0.02+0.05*npr.rand()*np.ones((D,))
sigmas0 = np.log((4e-5+2.5e-3*npr.rand()))*np.ones((D,))
test_acc.dynamics.params = (betas0, sigmas0, test_acc.dynamics.params[2])

# Initialize C, d
u_sum = np.array([np.sum(u[:,0] - u[:,1]) for u in us])
y_end = np.array([y[-10:] for y in ys])
y_U = y_end[np.where(u_sum>=25)]
y_L = y_end[np.where(u_sum<=-25)]
C_init = np.hstack((np.mean(y_U,axis=(0,1))[:,None],np.mean(y_L,axis=(0,1))[:,None])) / bin_size - test_acc.emissions.ds.T

test_acc.emissions.ds = (np.mean([y[0:3] for y in ys],axis=(0,1)) / bin_size).reshape((1,N))
test_acc.emissions.Cs[0] = C_init

# %%
q_elbos, q_lem = test_acc.fit(ys, inputs=us, method="laplace_em",
                              variational_posterior="structured_meanfield",
                              num_iters=25, alpha=0.5, initialize=False,
                              variational_posterior_kwargs={"initial_variance":1e-4})

# %%
plt.figure()
plt.plot(q_elbos[1:])
plt.xlabel("iteration")
plt.ylabel("ELBO")
plt.tight_layout()

# %%
def plot_trial(tr=0,legend=False):

    q_x = q_lem.mean_continuous_states[tr]
    zhat = test_acc.most_likely_states(q_x, ys[tr], input=us[tr])
    yhat = test_acc.smooth(q_x, ys[tr], input=us[tr])
    zhat = test_acc.most_likely_states(q_x, ys[tr], input=us[tr])

    J_diag = q_lem._params[tr]["J_diag"]
    J_lower_diag= q_lem._params[tr]["J_lower_diag"]
    J = blocks_to_full(J_diag, J_lower_diag)
    Jinv = np.linalg.inv(J)
    q_lem_std = np.sqrt(np.diag(Jinv))
    q_lem_std = q_lem_std.reshape((T,D))
    q_std_1 = q_lem_std[:,0]
    q_std_2 = q_lem_std[:,1]

    f, (a0, a1, a2, a3) = plt.subplots(4, 1, gridspec_kw={'height_ratios': [1, 0.5, 3, 1]}, figsize=[8,8])
    a0.imshow(np.row_stack((zs[tr], zhat)), aspect="auto", vmin=0, vmax=2)
    a0.set_xticks([])
    a0.set_yticks([0, 1], ["$z_{\\mathrm{true}}$", "$z_{\\mathrm{inf}}$"])
    a0.set_yticks([0,1])
    a0.set_yticklabels(["$z$", "$\hat{z}$"])
    a0.set_title("discrete latent")

    a1.plot(0.2*us[tr][:,0],color=[1.0,0.5,0.5], label=None,alpha=0.9)
    a1.plot(0.2*us[tr][:,1],color=[0.5,0.5,1.0], label=None,alpha=0.9)
    a1.set_yticks([])
    a1.set_xticks([])
    a1.axes.get_yaxis().set_visible(False)
    a1.set_title("input")

    a2.plot(xs[tr][:,0],color=[1.0,0.0,0.0],label="$x_1$",alpha=0.9)
    a2.plot(xs[tr][:,1],color=[0.0,0.0,1.0],label="$x_2$",alpha=0.9)
    a2.plot(q_x[:,0],color=[1.0,0.3,0.3],linestyle='--',label="$\hat{x}_1$",alpha=0.9)
    a2.plot(q_x[:,1],color=[0.3,0.3,1.0],linestyle='--',label="$\hat{x}_2$",alpha=0.9)

    a2.fill_between(np.arange(T),q_x[:,0]-q_std_1*2.0, q_x[:,0]+q_std_1*2.0, facecolor='r', alpha=0.3)
    a2.fill_between(np.arange(T),q_x[:,1]-q_std_2*2.0, q_x[:,1]+q_std_2*2.0, facecolor='b', alpha=0.3)
    a2.plot(np.array([0,100]),np.array([1,1]),'k--',linewidth=1.0,label=None)
    a2.set_ylim([-0.5,1.4])
    a2.set_xlim([-1,101])
    a2.set_xticks([])
    a2.set_yticks([0,1])
    a2.set_title("continuous latent")
    if legend:
        a2.legend()
    sns.despine()
    for n in range(10):
        a3.eventplot(np.where(ys[tr][:,n]>0)[0], linelengths=0.5, lineoffsets=1+n,color='k')
    sns.despine()
    a3.set_yticks([])
    a3.set_title("spikes")
    a3.set_xlim([-1,101])

    plt.tight_layout()

    return

# %%
tr = npr.randint(N_samples)
plot_trial(tr=tr, legend=True)

# %%
plt.figure(figsize=[6,3])
plt.subplot(121)
plt.imshow(np.concatenate((latent_acc.emissions.Cs[0],test_acc.emissions.Cs[0,:,:]),axis=1),aspect='auto', cmap="inferno")
plt.xticks([0.5, 2.5], ["$C_{\\mathrm{true}}$", "$C_{\\mathrm{inf}}$"])
plt.colorbar()

plt.subplot(122)
plt.imshow(np.concatenate((latent_acc.emissions.ds[0].reshape((N,1)),test_acc.emissions.ds.reshape((N,1))),axis=1),aspect='auto', cmap="inferno")
plt.xticks([0, 1], ["$d_{\\mathrm{true}}$", "$d_{\\mathrm{inf}}$"])
plt.colorbar()
plt.tight_layout()
